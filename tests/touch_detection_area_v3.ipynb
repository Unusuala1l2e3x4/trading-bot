# %%
import pandas as pd
import numpy as np
from alpaca.data.historical import StockHistoricalDataClient
from alpaca.data.requests import StockBarsRequest
from alpaca.trading import TradingClient
from alpaca.trading.requests import GetCalendarRequest
from alpaca.data.timeframe import TimeFrame
from alpaca.data.enums import Adjustment
# from datetime import date, datetime, timedelta
from datetime import datetime, date, time as datetime_time, timezone, timedelta
import pytz
import matplotlib.pyplot as plt
from collections import defaultdict
import numpy as np
import toml
import os
from dotenv import load_dotenv

import time

load_dotenv(override=True)
livepaper = os.getenv('LIVEPAPER')
config = toml.load('../config.toml')

# Replace with your Alpaca API credentials
API_KEY = config[livepaper]['key']
API_SECRET = config[livepaper]['secret']

# %%
from dataclasses import dataclass, field
from typing import List, Tuple
from datetime import datetime

@dataclass
class TouchArea:
    level: float
    upper_bound: float
    lower_bound: float
    touches: List[datetime]
    first_touch_price: float
    is_long: bool
    min_touches: int
    bid_buffer_pct: float
    entries_exits: List[Tuple[datetime, float, datetime, float]] = field(default_factory=list)

    def add_touch(self, touch_time: datetime):
        self.touches.append(touch_time)

    def add_entry_exit(self, entry_time: datetime, entry_price: float, exit_time: datetime, exit_price: float):
        self.entries_exits.append((entry_time, entry_price, exit_time, exit_price))

    def is_active(self) -> bool:
        return len(self.touches) >= self.min_touches

    def get_last_touch(self) -> datetime:
        return self.touches[-1] if self.touches else None

    def get_entry_price(self) -> float:
        return self.upper_bound * (1 + self.bid_buffer_pct / 100) if self.is_long else self.lower_bound * (1 - self.bid_buffer_pct / 100)

    def calculate_profit(self) -> float:
        total_profit = 0
        for entry_time, entry_price, exit_time, exit_price in self.entries_exits:
            if self.is_long:
                total_profit += exit_price - entry_price
            else:
                total_profit += entry_price - exit_price
        return total_profit

    def __str__(self):
        return (f"{'Long' if self.is_long else 'Short'} TouchArea: Level={self.level:.4f}, "
                f"Bounds={self.lower_bound:.4f}-{self.upper_bound:.4f}, "
                f"Touches={len(self.touches)}, Profit={self.calculate_profit():.4f}")

# %%
from datetime import datetime, timezone, timedelta

def to_datetime_with_timezone(date_str, tz_offset=0):
    """
    Converts a date string to a datetime object with specified timezone.

    :param date_str: The date string to convert (format: YYYY-MM-DD HH:MM:SS).
    :param tz_offset: The timezone offset in hours.
    :return: A datetime object representing the same date and time with specified timezone.
    """
    # Parse the date string to a datetime object
    
    datetime_obj = datetime.strptime(date_str, "%Y-%m-%d %H:%M:%S") if isinstance(date_str, str) else date_str
    
    # Create a timezone object with the specified offset
    timezone_obj = timezone(timedelta(hours=tz_offset))
    
    # Set the timezone for the datetime object
    datetime_obj = datetime_obj.replace(tzinfo=timezone_obj)
    
    return datetime_obj

# 2024-06-21 09:30:00 2024-06-21 16:00:00 <class 'datetime.datetime'>
# Example usage
# date_str = "2024-06-21 09:30:00"
# datetime_obj = to_datetime_with_timezone(date_str, tz_offset=0)

# print(datetime_obj)

# %%
dt_with_tz = datetime.now(pytz.timezone('US/Eastern'))

# Convert to the desired format
dt_str = str(dt_with_tz.strftime('%Y-%m-%d %H:%M:%S'))
dt_str
# Out:
# '2024-07-05 08:54:06'

# %%
def get_market_hours(dates):
    """
    Parameters:
    dates (list of str): List of dates in 'YYYY-MM-DD' format.

    Returns:
    dict: Dictionary with dates as keys and (market_open, market_close) tuples as values.
    """
    trading_client = TradingClient(API_KEY, API_SECRET)
    start_date = min(dates)
    end_date = max(dates)
    
    calendar_request = GetCalendarRequest(start=start_date, end=end_date)
    calendar = trading_client.get_calendar(calendar_request)
    
    market_hours = {str(day.date): (day.open, day.close) for day in calendar}
    return market_hours

# %%
def calculate_touch_detection_area(symbol, start_date, end_date, atr_period=10, multiplier=2, min_touches=2, bid_buffer_pct=0.005, sell_time=None, use_median=False):
    """
    Calculate the touch detection area based on custom volatility analysis and identify strong support and resistance levels,
    considering only market hours and selling all positions before a specified time.

    Parameters:
    symbol (str|list): The stock symbol to analyze.
    start_date (str|datetime): The start datetime for historical data (format: 'YYYY-MM-DD HH:MM:SS.%f').
    end_date (str|datetime): The end datetime for historical data (format: 'YYYY-MM-DD HH:MM:SS.%f').
    atr_period (int): The period for calculating Average True Range (ATR).
    multiplier (float): The multiplier for ATR to define the touch detection area width.
    min_touches (int): The minimum number of touches to consider a level as strong support or resistance.
    bid_buffer_pct (float): The percentage above the high or below the low to place a stop market buy.
    sell_time (str): The time to sell all positions before (format: 'HH:MM'). If None or after market close, defaults to market close.
    use_median (bool): Flag to switch between using mean or median for levels and touch areas.

    Returns:
    dict: A dictionary with support and resistance areas for both long and short positions.
    """
    # Alpaca API setup
    client = StockHistoricalDataClient(api_key=API_KEY, secret_key=API_SECRET)

    # Request historical data
    request_params = StockBarsRequest(
        symbol_or_symbols=symbol, # CAN be str or list. but set up for str (1 stock) for now)
        timeframe=TimeFrame.Minute,
        start=start_date if isinstance(start_date, datetime) else datetime.strptime(start_date, '%Y-%m-%d %H:%M:%S.%f'),
        end=end_date if isinstance(end_date, datetime) else datetime.strptime(end_date, '%Y-%m-%d %H:%M:%S.%f'),
        adjustment=Adjustment.ALL
    )
    bars = client.get_stock_bars(request_params)
    df = bars.df
    # print(pd.Series(list(df.index.get_level_values('timestamp').time)).value_counts().sort_index()) # gets trading hours range, including pre and post market
    
    
    # Calculate True Range (TR)
    df['H-L'] = df['high'] - df['low']
    df['H-PC'] = np.abs(df['high'] - df['close'].shift(1))
    df['L-PC'] = np.abs(df['low'] - df['close'].shift(1))
    df['TR'] = df[['H-L', 'H-PC', 'L-PC']].max(axis=1)

    if use_median:
        df['MTR'] = df['TR'].rolling(window=atr_period).median()
    else:
        df['ATR'] = df['TR'].rolling(window=atr_period).mean()
        
    timestamps = df.index.get_level_values('timestamp')
    # Identify potential support and resistance levels
    potential_levels = defaultdict(list)
    for i in range(1, len(df) - 1):
        if df['low'].iloc[i] <= df['low'].iloc[i-1] and df['low'].iloc[i] <= df['low'].iloc[i+1]:
            potential_levels[df['low'].iloc[i]].append(timestamps[i])  # Extract timestamp
        if df['high'].iloc[i] >= df['high'].iloc[i-1] and df['high'].iloc[i] >= df['high'].iloc[i+1]:
            potential_levels[df['high'].iloc[i]].append(timestamps[i])  # Extract timestamp
    
    strong_levels = {level: touches for level, touches in potential_levels.items() if len(touches) >= min_touches}

    central_value = df['close'].median() if use_median else df['close'].mean()
    
    # Define the upper and lower bounds for the touch areas
    support_levels = {level: touches for level, touches in strong_levels.items() if level <= central_value}
    resistance_levels = {level: touches for level, touches in strong_levels.items() if level > central_value}
    
    
    unique_dates = pd.unique(timestamps.date)
    timestamps = timestamps.strftime('%Y-%m-%d %H:%M:%S')
    date_strs = [str(date) for date in unique_dates]
    market_hours = get_market_hours(date_strs)
    
    if sell_time:
        sell_time = datetime.strptime(sell_time, '%H:%M')
        
    widths = []

    def calculate_touch_area(levels, is_long):
        touch_areas = []
        for level, touches in levels.items():
            n = len(touches)
            if n < min_touches:
                continue
            first_touch_price = df.loc[(symbol, touches[0]), 'close']
                
            if use_median:
                touch_area_width = np.mean([df.loc[(symbol, a), 'MTR'] for a in touches]) * multiplier
            else:
                touch_area_width = np.mean([df.loc[(symbol, a), 'ATR'] for a in touches]) * multiplier

            if np.isnan(touch_area_width):
                continue
            
            widths.append(touch_area_width)
            
            lower_bound = first_touch_price - (2 * touch_area_width / 3) if is_long else first_touch_price - (touch_area_width / 3)
            upper_bound = first_touch_price + (touch_area_width / 3) if is_long else first_touch_price + (2 * touch_area_width / 3)
            
            # Filter touches based on market hours and sell_time
            filtered_touches = []
            for touch_time in touches:
                touch_time = datetime.strptime(str(touch_time.strftime('%Y-%m-%d %H:%M:%S')), "%Y-%m-%d %H:%M:%S")
                touch_date = touch_time.date()
                market_open, market_close = market_hours.get(str(touch_date), (None, None))
                if sell_time:
                    market_close = min(
                        datetime.strptime(str(touch_date), '%Y-%m-%d') + timedelta(hours=sell_time.hour, minutes=sell_time.minute),
                        market_close - timedelta(minutes=3)
                    )
                if market_open and market_open <= touch_time <= market_close:
                    filtered_touches.append(touch_time)
            
            if filtered_touches:
                touch_area = TouchArea(
                    level=level,
                    upper_bound=upper_bound,
                    lower_bound=lower_bound,
                    touches=filtered_touches,
                    first_touch_price=first_touch_price,
                    is_long=is_long,
                    min_touches=min_touches,
                    bid_buffer_pct=bid_buffer_pct
                )
                touch_areas.append(touch_area)
        return touch_areas


    long_touch_area = calculate_touch_area(resistance_levels, True)
    short_touch_area = calculate_touch_area(support_levels, False)
    # print(len(long_touch_area), len(short_touch_area))
    
    widths = pd.Series(widths)
    print(widths.describe())
    print(widths.isna().value_counts())
    
    final_mask = pd.Series(False, index=df.index)
    for date in unique_dates:
        market_open, market_close = market_hours.get(str(date), (None, None))
        date = datetime.strptime(str(date), '%Y-%m-%d')
        if market_open is None or market_close is None:
            market_open = market_close = date
        elif sell_time:
            market_close = date + timedelta(hours=sell_time.hour, minutes=sell_time.minute)
        mask = (timestamps >= str(market_open)) & (timestamps <= str(market_close))
        final_mask |= mask

    return {
        'long_touch_area': long_touch_area,
        'short_touch_area': short_touch_area,
        'market_hours': market_hours,
        'bars': df,
        'mask': final_mask,
        'bid_buffer_pct': bid_buffer_pct,
        'min_touches': min_touches,
        'sell_time': sell_time,
        'use_median': use_median
    }

# %%
def plot_touch_detection_areas(touch_detection_areas, symbol, save_path=None):
    long_touch_area = touch_detection_areas['long_touch_area']
    short_touch_area = touch_detection_areas['short_touch_area']
    market_hours = touch_detection_areas['market_hours']
    df = touch_detection_areas['bars']
    mask = touch_detection_areas['mask']
    bid_buffer_pct = touch_detection_areas['bid_buffer_pct']
    min_touches = touch_detection_areas['min_touches']
    sell_time = touch_detection_areas['sell_time']
    use_median = touch_detection_areas['use_median']

    # 
    plt.figure(figsize=(14, 7))
    plt.plot(df.index.get_level_values('timestamp'), df['close'], label='Close Price', color='blue') # before applying mask, plot the full chart
    
    # print(pd.Series(list(df.index.get_level_values('timestamp').time)).value_counts().sort_index())
    df = df[mask]
    timestamps = df.index.get_level_values('timestamp')

    # Fetch market hours for the relevant dates
    # timestamps = timestamps.strftime('%Y-%m-%d %H:%M:%S')
    # timestamps = timestamps.to_pydatetime()
    
    timestamps_set = {a.replace(tzinfo=None) for a in timestamps}

    def get_touch_area_end_idx(start_idx, bound, is_long=True, touch_time=None):
        # Determine the date of the touch event
        touch_date = touch_time.date()
        
        # Fetch market open and close times for the given date
        market_open, market_close = market_hours.get(str(touch_date), (None, None))
        
        # If a sell time is specified, adjust the market close time to be the sell time or slightly before the actual market close
        if sell_time:
            market_close = min(
                datetime.strptime(str(touch_date), '%Y-%m-%d') + timedelta(hours=sell_time.hour, minutes=sell_time.minute),
                market_close - timedelta(minutes=3)
            )
        
        # Iterate through the DataFrame from the start index to find the sell time index
        for i in range(start_idx, len(df)):
            # Remove timezone information from the current timestamp for comparison
            current_time = timestamps[i].replace(tzinfo=None)
            
            # If the current time exceeds the adjusted market close time, return the previous index
            if current_time > market_close:
                return i - 1
            
            # If the price exceeds the bound for long positions or falls below the bound for short positions, return the current index
            if (is_long and df['close'].iloc[i] > bound * (1 + bid_buffer_pct / 100)) or (not is_long and df['close'].iloc[i] < bound * (1 - bid_buffer_pct / 100)):
                return i
        
        # If no appropriate index is found, return the last index of the DataFrame
        return len(df) - 1

    def plot_area(area: TouchArea):
        if not area.is_active():
            return

        mark_pos = area.upper_bound if area.is_long else area.lower_bound
        mark_shape = "v" if area.is_long else '^'
        
        for i, touch_time in enumerate(area.touches):
            if touch_time in timestamps_set:
                start_idx = timestamps.get_loc(str(touch_time))
                end_idx = get_touch_area_end_idx(start_idx, area.upper_bound if area.is_long else area.lower_bound, area.is_long, touch_time)
                x = [timestamps[start_idx], timestamps[end_idx]]
                
                if i != min_touches - 1:
                    pass
                else:  # min_touches met
                    if end_idx == start_idx:
                        plt.scatter(touch_time, mark_pos, color='red', s=12, marker=mark_shape)
                    else:
                        plt.scatter(touch_time, mark_pos, color='blue', s=12, marker=mark_shape)
                
                if i == 0:  # first touch
                    color = 'red' if area.is_long else 'green'
                    plt.fill_between(x, area.lower_bound, area.upper_bound, color=color, alpha=0.3)
                    plt.plot(x, [area.first_touch_price, area.first_touch_price], color='blue', linestyle='-')

    for area in long_touch_area:
        plot_area(area)

    for area in short_touch_area:
        plot_area(area)

    plt.title(f'{symbol} Price Chart with Touch Detection Areas')
    plt.xlabel('Date')
    plt.ylabel('Price')
    # plt.legend(['Close Price', 'Long Touch Area', 'Short Touch Area'])
    plt.legend().remove()
    plt.grid(True)

    if save_path:
        plt.savefig(save_path)

    plt.show()

# %%
# symbol = "NVDA"
symbol = "META"

# start_date=datetime.strptime(start_date, '%Y-%m-%d %H:%M:%S%z'),
# end=datetime.strptime("2023-12-02 00:00:00+00:00" , '%Y-%m-%d %H:%M:%S%z').str
# '2024-07-03 02:15:18.202708'
# start_date = datetime.strptime("2024-06-21 9:00:00.0", '%Y-%m-%d %H:%M:%S.%f')

# end_date = start_date + timedelta(hours=12)

# end_date = "2023-12-02 00:00:00.0" 

# start_date = datetime.today() - timedelta(hours=36)
# end_date = datetime.today()
start_date = "2024-06-01 08:00:00.0"
end_date = "2024-06-30 16:00:00.0"
# min_touches = 3
touch_detection_areas = calculate_touch_detection_area(symbol, start_date, end_date, atr_period=30, multiplier=1, min_touches=3, sell_time='16:00', use_median=True)
plot_touch_detection_areas(touch_detection_areas, symbol)
# Out:
# count    591.000000
# mean       0.343956
# std        0.116365
# min        0.045625
# 25%        0.265131
# 50%        0.336237
# 75%        0.416579
# max        0.808333
# dtype: float64
# False    591
# Name: count, dtype: int64

# %%
def backtest_strategy(touch_detection_areas, initial_investment=10000):
    df = touch_detection_areas['bars']
    long_touch_area = touch_detection_areas['long_touch_area']
    short_touch_area = touch_detection_areas['short_touch_area']
    market_hours = touch_detection_areas['market_hours']
    bid_buffer_pct = touch_detection_areas['bid_buffer_pct']
    min_touches = touch_detection_areas['min_touches']
    sell_time = touch_detection_areas['sell_time']
    timestamps = df.index.get_level_values('timestamp')

    balance = initial_investment
    trades_executed = 0

    def get_touch_area_end_idx(start_idx, bound, is_long=True, touch_time=None):
        # Determine the date of the touch event
        touch_date = touch_time.date()
        
        # Fetch market open and close times for the given date
        market_open, market_close = market_hours.get(str(touch_date), (None, None))
        
        # If a sell time is specified, adjust the market close time to be the sell time or slightly before the actual market close
        if sell_time:
            market_close = min(
                datetime.strptime(str(touch_date), '%Y-%m-%d') + timedelta(hours=sell_time.hour, minutes=sell_time.minute),
                market_close - timedelta(minutes=3)
            )
        
        # Iterate through the DataFrame from the start index to find the sell time index
        for i in range(start_idx, len(df)):
            # Remove timezone information from the current timestamp for comparison
            current_time = timestamps[i].replace(tzinfo=None)
            
            # If the current time exceeds the adjusted market close time, return the previous index
            if current_time > market_close:
                return i - 1
            
            # If the price exceeds the bound for long positions or falls below the bound for short positions, return the current index
            if (is_long and df['close'].iloc[i] > bound * (1 + bid_buffer_pct / 100)) or (not is_long and df['close'].iloc[i] < bound * (1 - bid_buffer_pct / 100)):
                return i
        
        # If no appropriate index is found, return the last index of the DataFrame
        return len(df) - 1

    def execute_trade(start_idx, stop_price, is_long):
        nonlocal balance, trades_executed
        shares = balance / df['close'].iloc[start_idx]
        max_price = df['close'].iloc[start_idx]
        min_price = df['close'].iloc[start_idx]
        
        for i in range(start_idx + 1, len(df)):
            current_price = df['close'].iloc[i]
            if is_long:
                max_price = max(max_price, current_price)
                trailing_stop_price = max_price * (1 - bid_buffer_pct / 100)
                if current_price <= trailing_stop_price:
                    balance = shares * trailing_stop_price
                    trades_executed += 1
                    break
            else:
                min_price = min(min_price, current_price)
                trailing_stop_price = min_price * (1 + bid_buffer_pct / 100)
                if current_price >= trailing_stop_price:
                    balance = shares * trailing_stop_price
                    trades_executed += 1
                    break
        else:
            balance = shares * df['close'].iloc[-1]
            trades_executed += 1

    timestamps_set = {a.replace(tzinfo=None) for a in timestamps}
    
    def process_touch_areas(touch_areas):
        nonlocal balance, trades_executed
        for area in touch_areas:
            if area.is_active():
                for touch_time in area.touches[min_touches - 1:]:
                    if touch_time in timestamps_set:
                        start_idx = timestamps.get_loc(str(touch_time))
                        end_idx = get_touch_area_end_idx(start_idx, area.get_entry_price(), area.is_long, touch_time)
                        stop_price = df['close'][end_idx]
                        
                        entry_time = timestamps[start_idx]
                        entry_price = df['close'].iloc[start_idx]
                        exit_time = timestamps[end_idx]
                        exit_price = df['close'].iloc[end_idx]
                        
                        area.add_entry_exit(entry_time, entry_price, exit_time, exit_price)
                        
                        execute_trade(end_idx, stop_price, area.is_long)

    # Process long and short touch areas
    process_touch_areas(long_touch_area)
    process_touch_areas(short_touch_area)

    percent_increase = ((balance - initial_investment) / initial_investment) * 100

    # Buy and hold strategy
    start_price = df['close'].iloc[0]
    end_price = df['close'].iloc[-1]
    buy_and_hold_increase = ((end_price - start_price) / start_price) * 100

    # Print statistics
    print('Initial Investment:', initial_investment)
    print('Current Balance:', balance)
    print('Net:', balance - initial_investment)
    print(f"Percent increase: {percent_increase:.2f}%")
    print(f"Buy and Hold percent increase: {buy_and_hold_increase:.2f}%")
    print('Number of Trades Executed:', trades_executed)


    for area in long_touch_area + short_touch_area:
        if area.is_active():
            print(area)
    
print(symbol)
backtest_strategy(touch_detection_areas)
# Out:
# META
# C:\Users\alexw\AppData\Local\Temp\ipykernel_65744\1730334429.py:80: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   stop_price = df['close'][end_idx]
# Initial Investment: 10000
# Current Balance: 10175.459159603666
# Net: 175.4591596036662
# Percent increase: 1.75%
# Buy and Hold percent increase: 7.81%
# Number of Trades Executed: 284
# Long TouchArea: Level=502.3200, Bounds=501.4508-501.9446, Touches=3, Profit=-1.7950
# Long TouchArea: Level=501.5000, Bounds=501.1712-501.4394, Touches=3, Profit=0.0000
# Long TouchArea: Level=501.5300, Bounds=501.2822-501.6539, Touches=3, Profit=0.0800
# Long TouchArea: Level=502.0700, Bounds=501.5658-502.0821, Touches=3, Profit=0.0000
# Long TouchArea: Level=502.0000, Bounds=501.8674-502.0663, Touches=14, Profit=2.9598
# Long TouchArea: Level=501.3000, Bounds=501.1651-501.3674, Touches=4, Profit=0.4400
# Long TouchArea: Level=504.8300, Bounds=504.3078-504.9861, Touches=3, Profit=-1.4500
# Long TouchArea: Level=504.4900, Bounds=503.9411-504.2994, Touches=3, Profit=1.5350
# Long TouchArea: Level=502.7400, Bounds=502.8021-503.1439, Touches=3, Profit=0.5577
# Long TouchArea: Level=503.2600, Bounds=502.8659-503.2470, Touches=3, Profit=0.0000
# Long TouchArea: Level=502.0800, Bounds=501.9787-502.5657, Touches=3, Profit=1.1713
# Long TouchArea: Level=502.2000, Bounds=501.9736-502.3132, Touches=6, Profit=1.2335
# Long TouchArea: Level=502.7000, Bounds=502.0383-502.3559, Touches=3, Profit=0.0000
# Long TouchArea: Level=502.0200, Bounds=501.8461-502.3620, Touches=5, Profit=1.0458
# Long TouchArea: Level=502.5700, Bounds=502.1999-502.5750, Touches=6, Profit=-0.2800
# Long TouchArea: Level=503.1000, Bounds=502.7426-503.0237, Touches=4, Profit=0.2844
# Long TouchArea: Level=501.7000, Bounds=501.8370-502.0065, Touches=4, Profit=2.5800
# Long TouchArea: Level=501.5200, Bounds=501.3463-501.6069, Touches=3, Profit=0.0000
# Long TouchArea: Level=503.6800, Bounds=503.1340-503.5180, Touches=3, Profit=0.0000
# Long TouchArea: Level=503.7000, Bounds=503.4200-503.7200, Touches=3, Profit=-3.0000
# Long TouchArea: Level=504.0000, Bounds=503.5752-503.8824, Touches=4, Profit=0.0000
# Long TouchArea: Level=504.7000, Bounds=504.5649-505.1276, Touches=5, Profit=1.6850
# Long TouchArea: Level=505.5000, Bounds=505.2434-505.5083, Touches=5, Profit=1.1600
# Long TouchArea: Level=506.5000, Bounds=506.2417-506.5092, Touches=5, Profit=0.9400
# Long TouchArea: Level=507.5000, Bounds=507.3316-507.5842, Touches=11, Profit=2.7600
# Long TouchArea: Level=507.4000, Bounds=507.4905-507.8798, Touches=4, Profit=3.0900
# Long TouchArea: Level=507.3700, Bounds=507.1014-507.3993, Touches=5, Profit=1.4800
# Long TouchArea: Level=507.0000, Bounds=506.8156-507.0922, Touches=3, Profit=0.5100
# Long TouchArea: Level=507.1500, Bounds=506.9450-507.2525, Touches=3, Profit=-4.9100
# Long TouchArea: Level=508.2100, Bounds=508.0256-508.3022, Touches=3, Profit=0.2900
# Long TouchArea: Level=508.5000, Bounds=508.3367-508.5816, Touches=3, Profit=0.5000
# Long TouchArea: Level=507.1900, Bounds=507.2058-507.5271, Touches=3, Profit=0.6200
# Long TouchArea: Level=507.2100, Bounds=506.6567-507.1267, Touches=3, Profit=0.0000
# Long TouchArea: Level=507.1700, Bounds=507.3567-507.5717, Touches=3, Profit=0.0000
# Long TouchArea: Level=514.4900, Bounds=513.1722-513.6489, Touches=3, Profit=0.0000
# Long TouchArea: Level=513.4900, Bounds=513.4211-513.8094, Touches=3, Profit=0.3200
# Long TouchArea: Level=514.7500, Bounds=514.5043-514.8728, Touches=3, Profit=1.4300
# Long TouchArea: Level=506.3500, Bounds=505.1762-505.8269, Touches=3, Profit=0.0000
# Long TouchArea: Level=506.2000, Bounds=506.2778-506.6261, Touches=3, Profit=1.6000
# Long TouchArea: Level=506.0000, Bounds=504.8022-505.0539, Touches=5, Profit=0.3018
# Long TouchArea: Level=506.3400, Bounds=505.8295-506.3853, Touches=3, Profit=0.0000
# Long TouchArea: Level=508.3000, Bounds=508.0795-508.3203, Touches=5, Profit=2.2600
# Long TouchArea: Level=508.7000, Bounds=508.2967-508.6916, Touches=3, Profit=0.8790
# Long TouchArea: Level=509.0000, Bounds=508.5085-508.8857, Touches=3, Profit=0.6690
# Long TouchArea: Level=507.6200, Bounds=507.4467-507.7067, Touches=3, Profit=1.1000
# Long TouchArea: Level=503.8700, Bounds=504.1945-504.5928, Touches=3, Profit=-7.4350
# Long TouchArea: Level=501.7500, Bounds=502.5050-503.0375, Touches=4, Profit=-0.3716
# Long TouchArea: Level=503.5200, Bounds=503.2842-503.6379, Touches=3, Profit=-3.1100
# Long TouchArea: Level=503.3700, Bounds=503.6675-504.0913, Touches=3, Profit=-1.4821
# Long TouchArea: Level=504.0900, Bounds=503.6134-504.0433, Touches=3, Profit=0.0000
# Long TouchArea: Level=504.3000, Bounds=504.1330-504.5785, Touches=4, Profit=-3.4500
# Long TouchArea: Level=504.1200, Bounds=504.1058-504.4421, Touches=3, Profit=2.2450
# Long TouchArea: Level=504.5000, Bounds=504.2267-504.4417, Touches=4, Profit=0.0000
# Long TouchArea: Level=503.3000, Bounds=503.3522-503.7689, Touches=3, Profit=1.7400
# Long TouchArea: Level=503.0000, Bounds=502.8562-503.0719, Touches=4, Profit=-2.5900
# Long TouchArea: Level=502.5000, Bounds=502.3638-502.5681, Touches=4, Profit=-1.4600
# Long TouchArea: Level=505.6400, Bounds=504.7817-504.9592, Touches=4, Profit=0.0000
# Long TouchArea: Level=503.3100, Bounds=503.2939-503.8355, Touches=3, Profit=0.4750
# Long TouchArea: Level=502.6900, Bounds=502.9037-503.4720, Touches=3, Profit=0.1550
# Long TouchArea: Level=502.5500, Bounds=502.0904-502.3223, Touches=4, Profit=0.0000
# Long TouchArea: Level=501.6600, Bounds=501.3988-501.8356, Touches=4, Profit=0.5007
# Long TouchArea: Level=502.9000, Bounds=502.5223-502.7513, Touches=3, Profit=0.0000
# Long TouchArea: Level=503.3600, Bounds=502.9227-503.2637, Touches=3, Profit=-1.2095
# Long TouchArea: Level=502.2800, Bounds=502.3978-502.6336, Touches=3, Profit=-1.7900
# Long TouchArea: Level=502.7500, Bounds=502.5285-502.8608, Touches=5, Profit=0.2500
# Long TouchArea: Level=501.4500, Bounds=501.1090-501.4555, Touches=3, Profit=0.2450
# Long TouchArea: Level=501.8000, Bounds=501.2511-501.7444, Touches=3, Profit=0.7050
# Long TouchArea: Level=501.3300, Bounds=501.2067-501.6167, Touches=3, Profit=-1.7300
# Long TouchArea: Level=508.8500, Bounds=508.6433-508.8933, Touches=4, Profit=7.1600
# Long TouchArea: Level=510.0000, Bounds=509.7011-509.9844, Touches=3, Profit=0.0000
# Long TouchArea: Level=512.0000, Bounds=511.8340-512.0830, Touches=5, Profit=0.9000
# Long TouchArea: Level=511.0000, Bounds=511.6037-512.0781, Touches=3, Profit=0.6000
# Long TouchArea: Level=512.3000, Bounds=512.4105-512.7435, Touches=3, Profit=0.2903
# Long TouchArea: Level=518.0000, Bounds=517.8272-518.2664, Touches=5, Profit=3.9400
# Long TouchArea: Level=516.5000, Bounds=516.1438-516.5782, Touches=3, Profit=0.3000
# Long TouchArea: Level=517.5000, Bounds=516.4905-517.0748, Touches=3, Profit=1.0600
# Short TouchArea: Level=468.1400, Bounds=468.0744-468.2711, Touches=3, Profit=0.4000
# Short TouchArea: Level=467.8400, Bounds=467.7996-467.9208, Touches=4, Profit=0.6600
# Short TouchArea: Level=474.0300, Bounds=473.1257-473.6187, Touches=5, Profit=3.8000
# Short TouchArea: Level=474.5300, Bounds=475.1117-475.6467, Touches=3, Profit=0.0000
# Short TouchArea: Level=474.1300, Bounds=474.1283-474.9133, Touches=3, Profit=0.8000
# Short TouchArea: Level=474.3000, Bounds=474.1587-474.5825, Touches=3, Profit=0.1700
# Short TouchArea: Level=473.5300, Bounds=473.4194-473.7511, Touches=3, Profit=-0.7300
# Short TouchArea: Level=473.4800, Bounds=473.4022-473.6356, Touches=3, Profit=0.1600
# Short TouchArea: Level=473.8200, Bounds=474.1261-474.5578, Touches=3, Profit=0.0000
# Short TouchArea: Level=482.0200, Bounds=481.9254-482.2093, Touches=9, Profit=-3.2800
# Short TouchArea: Level=481.5200, Bounds=481.4158-481.7283, Touches=4, Profit=5.4600
# Short TouchArea: Level=483.5200, Bounds=483.6819-483.9162, Touches=7, Profit=0.0000
# Short TouchArea: Level=482.9200, Bounds=482.8178-483.1244, Touches=3, Profit=0.2500
# Short TouchArea: Level=482.8300, Bounds=482.7250-483.0400, Touches=3, Profit=0.2500
# Short TouchArea: Level=481.1200, Bounds=481.0383-481.2833, Touches=3, Profit=-1.8300
# Short TouchArea: Level=482.2700, Bounds=482.1912-482.4275, Touches=4, Profit=-2.9100
# Short TouchArea: Level=482.5200, Bounds=482.4710-482.6180, Touches=5, Profit=-3.6700
# Short TouchArea: Level=493.5100, Bounds=493.4153-493.6993, Touches=11, Profit=5.4800
# Short TouchArea: Level=494.5100, Bounds=493.8471-494.3359, Touches=7, Profit=-14.8600
# Short TouchArea: Level=494.2600, Bounds=494.1383-494.5033, Touches=3, Profit=-1.9000
# Short TouchArea: Level=492.0100, Bounds=491.9377-492.1545, Touches=5, Profit=-26.3300
# Short TouchArea: Level=492.7600, Bounds=492.6731-492.9339, Touches=3, Profit=0.2600
# Short TouchArea: Level=493.1100, Bounds=492.9597-493.4107, Touches=3, Profit=0.0000
# Short TouchArea: Level=493.5200, Bounds=493.4006-493.7289, Touches=3, Profit=1.1000
# Short TouchArea: Level=494.7100, Bounds=494.5472-495.0356, Touches=3, Profit=0.7800
# Short TouchArea: Level=492.3600, Bounds=492.1294-492.3411, Touches=3, Profit=0.3500
# Short TouchArea: Level=492.8100, Bounds=492.3861-492.8478, Touches=3, Profit=0.6700
# Short TouchArea: Level=492.8700, Bounds=492.7577-493.0947, Touches=3, Profit=-2.8900
# Short TouchArea: Level=492.2700, Bounds=492.2167-492.3767, Touches=3, Profit=0.1300
# Short TouchArea: Level=495.0100, Bounds=494.6470-495.0160, Touches=3, Profit=-5.5400
# Short TouchArea: Level=497.4900, Bounds=497.2054-497.6393, Touches=3, Profit=0.9800
# Short TouchArea: Level=500.0000, Bounds=500.8156-501.1888, Touches=5, Profit=0.0000
# Short TouchArea: Level=500.0100, Bounds=500.2397-500.8706, Touches=3, Profit=0.7700
# Short TouchArea: Level=500.6400, Bounds=500.2376-500.8449, Touches=3, Profit=0.6500
# Short TouchArea: Level=497.1100, Bounds=497.3137-497.9025, Touches=3, Profit=0.3100
# Short TouchArea: Level=497.2500, Bounds=496.9269-497.3561, Touches=3, Profit=-4.7055
# Short TouchArea: Level=496.8500, Bounds=497.0167-497.5067, Touches=3, Profit=0.0000
# Short TouchArea: Level=497.7600, Bounds=497.4788-498.0225, Touches=3, Profit=-4.1955
# Short TouchArea: Level=496.1200, Bounds=496.3629-496.8042, Touches=4, Profit=0.6000
# Short TouchArea: Level=495.3100, Bounds=495.4150-495.7600, Touches=3, Profit=0.0000
# Short TouchArea: Level=496.3000, Bounds=496.0896-496.4807, Touches=3, Profit=-3.7000
# Short TouchArea: Level=496.5600, Bounds=496.1452-496.4895, Touches=4, Profit=0.7600
# Short TouchArea: Level=495.5000, Bounds=495.1092-495.5015, Touches=3, Profit=-10.4710
# Short TouchArea: Level=495.5100, Bounds=492.7363-493.2875, Touches=4, Profit=-6.1500
# Short TouchArea: Level=494.5500, Bounds=494.5044-494.9711, Touches=3, Profit=-1.0500
# Short TouchArea: Level=496.8000, Bounds=496.6801-497.1298, Touches=4, Profit=0.0000
# Short TouchArea: Level=494.2700, Bounds=494.5872-495.0156, Touches=3, Profit=0.5700
# Short TouchArea: Level=493.9500, Bounds=494.0735-494.4831, Touches=3, Profit=-2.2400
# Short TouchArea: Level=494.9500, Bounds=494.7935-494.9931, Touches=3, Profit=0.4506
# Short TouchArea: Level=495.8000, Bounds=495.1850-495.4100, Touches=3, Profit=-6.1555
# Short TouchArea: Level=496.2800, Bounds=495.6767-496.2867, Touches=3, Profit=0.0000
# Short TouchArea: Level=496.0100, Bounds=495.4751-495.9097, Touches=3, Profit=-5.6000
# Short TouchArea: Level=498.3000, Bounds=497.7875-497.9749, Touches=6, Profit=6.0600
# Short TouchArea: Level=497.7500, Bounds=497.7495-498.0210, Touches=3, Profit=0.5000
# Short TouchArea: Level=496.5100, Bounds=494.7840-495.1921, Touches=3, Profit=-5.4455
# Short TouchArea: Level=501.0800, Bounds=500.4903-500.7293, Touches=3, Profit=1.1300
# Short TouchArea: Level=500.0400, Bounds=500.3458-500.7183, Touches=5, Profit=0.7800
# Short TouchArea: Level=501.2700, Bounds=501.0133-501.3633, Touches=3, Profit=0.5100
# Short TouchArea: Level=501.2500, Bounds=500.9160-501.2580, Touches=3, Profit=0.7200
# Short TouchArea: Level=499.7000, Bounds=498.9210-499.0980, Touches=4, Profit=2.9950
# Short TouchArea: Level=499.5000, Bounds=499.4424-499.6152, Touches=3, Profit=1.7600
# Short TouchArea: Level=499.1900, Bounds=499.3854-499.6692, Touches=3, Profit=0.0000
# Short TouchArea: Level=500.5000, Bounds=500.2190-500.4621, Touches=6, Profit=-0.0503
# Short TouchArea: Level=500.1000, Bounds=500.0970-500.3460, Touches=4, Profit=0.8700
# Short TouchArea: Level=500.8000, Bounds=500.7242-500.9517, Touches=3, Profit=0.2000
# Short TouchArea: Level=501.0000, Bounds=500.9035-501.1930, Touches=7, Profit=3.6236
# Short TouchArea: Level=500.9000, Bounds=500.8228-501.0543, Touches=4, Profit=0.7850
# Short TouchArea: Level=500.2300, Bounds=499.8763-500.1274, Touches=3, Profit=0.9700
# Short TouchArea: Level=500.0800, Bounds=499.9733-500.2933, Touches=3, Profit=0.0000
# Short TouchArea: Level=500.7500, Bounds=500.2467-500.5567, Touches=6, Profit=-0.4308
# Short TouchArea: Level=498.7500, Bounds=500.5996-501.0808, Touches=4, Profit=0.0000
# Short TouchArea: Level=501.2000, Bounds=501.6040-502.0421, Touches=3, Profit=0.0000
# Short TouchArea: Level=500.7200, Bounds=500.6729-501.0242, Touches=3, Profit=0.4200
# Short TouchArea: Level=499.6100, Bounds=499.5083-499.8733, Touches=3, Profit=-8.7210
# Short TouchArea: Level=497.6000, Bounds=497.3158-497.6733, Touches=4, Profit=-8.4110
# Short TouchArea: Level=500.8700, Bounds=501.0045-501.2010, Touches=3, Profit=0.0000
# Short TouchArea: Level=498.1100, Bounds=498.1535-498.5907, Touches=4, Profit=0.1100
# Short TouchArea: Level=498.6000, Bounds=498.2368-498.5464, Touches=3, Profit=2.4100
# Short TouchArea: Level=498.7000, Bounds=498.4754-498.8793, Touches=7, Profit=3.5600
# Short TouchArea: Level=497.3300, Bounds=496.9194-497.5061, Touches=3, Profit=0.4550
# Short TouchArea: Level=497.8000, Bounds=497.6900-498.0200, Touches=3, Profit=0.5500
# Short TouchArea: Level=498.0000, Bounds=497.9467-498.1067, Touches=8, Profit=2.8400
